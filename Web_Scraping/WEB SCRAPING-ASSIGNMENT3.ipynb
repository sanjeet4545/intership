# %% [markdown]
# # WEB SCRAPING-ASSIGNMENT3

# %%
# Importing libaraies
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
import re

# Importing Selenium webdriver
from selenium import webdriver
from selenium.webdriver.common.by import By

# Importing requireds exceptions which need to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# Importing requests
import requests

# %% [markdown]
# # Q-1 and Q2 are connceted

# %% [markdown]
# ### 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
# Connecting to the webdriver
driver = webdriver.Chrome()

# Open amazon url in webdriver
driver.get("https://www.amazon.in/")
time.sleep(2)

# %%
# Takeing a input from user about the product search
User_input = input('Enter Product Name : ')
# Out:
# Enter Product Name : guitars

# %%
# Find Search menu 
search = driver.find_element(By.XPATH,'//input[@id="twotabsearchtextbox"]')
search.clear()
search.send_keys(User_input)

# Search_button
search_button = driver.find_element(By.XPATH,'//input[@id="nav-search-submit-button"]')
search_button.click()

# %% [markdown]
# ### 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv.
#
# ***In case if any product has less than 3 pages in search results thenscrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“. ***

# %%
# creating an empty list for scrap data
Brand = []
Product = []
Price = []
Return = []
Delivery = []
Availability = []
URL = []

# %%
URL = []
start = 0
end = 2
for page in range(start,end):
    url = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        URL.append(i.get_attribute('href'))
    time.sleep(2)
    next_button = driver.find_elements(By.XPATH,'//a[@aria-label="Go to next page, page 2"]')

# %%
len(URL)
# Out:
# 128

# %%
# iterating each and every url to fectch
from tqdm import tqdm
for i in tqdm(URL):
    driver.get(i)
    time.sleep(3)

    # Extracting Brand
    try:
        brand_tag = driver.find_element(By.XPATH,'//a[@id="bylineInfo"]')
        Brand.append(brand_tag.text)
    except NoSuchElementException:
        Brand.append('-')
        
    time.sleep(1)
    
    # Extracting Product
    try:
        product_tag = driver.find_element(By.XPATH,'//span[@id="productTitle"]')
        Product.append(product_tag.text)
    except NoSuchElementException:
        Product.append('-')
        
    time.sleep(1)
        
    # Extracting Price
    
    try:
        price_tag = driver.find_element(By.XPATH,'//span[@class="a-price-whole"]')
        Price.append(price_tag.text)
    except NoSuchElementException:
        Price.append('-')
        
    time.sleep(1)
    
    # Extracting Return
    
    try:
        return_tag = driver.find_element(By.XPATH,'//*[@id="RETURNS_POLICY"]/span/div[2]')
        Return.append(return_tag.text)
    except NoSuchElementException:
        Return.append('-')
        
    time.sleep(1)
    
    # Extracting Delivery
    try: 
        delivery_tag = driver.find_element(By.XPATH,'//div[@id="deliveryBlockMessage"]')
        Delivery.append(delivery_tag.text)
    except NoSuchElementExcpetion:
        Delivery.append('-')
    
    time.sleep(1)
    
    # Extracting Availability
    try:
        availability_tag = driver.find_element(By.XPATH,'//span[@class="a-size-medium a-color-success"]')
        Availability.append(availability_tag.text)
    except NoSuchElementException:
        Availability.append('-')
        
    time.sleep(1)
    
    driver.close()
# Out:
# 100%|██████████| 128/128 [29:36<00:00, 13.88s/it]

# %%
print(len(Brand),len(Product),len(Price),len(Return),len(Delivery),len(Availability),len(URL))
# Out:
# 128 128 128 128 128 128 128

# %%
# Create a DataFrame
guitars = pd.DataFrame({'Brand':Brand,'Product':Product,'Price':Price,'Return/Exchange':Return,'Expected Delivery':Delivery,'Availability':Availability,'URL':URL})

guitars
# Out:
#                          Brand  \
# 0      Visit the Kadence Store
# 1      Visit the Kadence Store
# 2      Visit the Kadence Store
# 3                 Brand: REVEL
# 4       Visit the JUAREZ Store
# ..                         ...
# 123  Visit the blueberry Store
# 124    Visit the Kadence Store
# 125        Brand: PS Signature
# 126        Brand: PS Signature
# 127    Visit the Kadence Store
#
#                                                Product   Price  \
# 0    Kadence rosewood Guitar Frontier Series, Elect...   4,999
# 1    Kadence Frontier guitar with Online Guitar lea...   4,299
# 2    Kadence Slowhand Premium Jumbo Semi Acoustic G...  11,999
# 3    Revel Acoustic Guitar with Carry bag and Plect...   1,999
# 4    Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...   2,369
# ..                                                 ...     ...
# 123  Blueberry, VIP 341, 34 Inch Sapele Natural Woo...   3,290
# 124  Kadence rosewood Guitar Frontier Series, Elect...   4,999
# 125  PS Signature 41inch Acoustic Guitar Black Matt...   3,324
# 126  PS Signature 41inch Acoustic Guitar (Natural C...   3,419
# 127  Kadence Slowhand Premium Jumbo Semi Acoustic G...  11,999
#
#         Return/Exchange                                  Expected Delivery  \
# 0    7 days Replacement  FREE delivery Saturday, 7 October. Order withi...
# 1    7 days Replacement  FREE delivery Friday, 6 October. Order within ...
# 2    7 days Replacement  FREE delivery Saturday, 7 October. Order withi...
# 3    7 days Replacement         FREE delivery Saturday, 7 October. Details
# 4    7 days Replacement  FREE delivery Saturday, 7 October. Order withi...
# ..                  ...                                                ...
# 123  7 days Replacement         FREE delivery Thursday, 5 October. Details
# 124  7 days Replacement  FREE delivery Saturday, 7 October. Order withi...
# 125   7 days Returnable  FREE delivery Saturday, 7 October. Order withi...
# 126  7 days Replacement  FREE delivery Saturday, 7 October. Order withi...
# 127  7 days Replacement  FREE delivery Friday, 6 October. Order within ...
#
#     Availability                                                URL
# 0       In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1       In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2       In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 3       In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 4       In stock  https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ..           ...                                                ...
# 123            -  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 124     In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 125     In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 126     In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 127     In stock  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
#
# [128 rows x 7 columns]

# %% [markdown]
# ### 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %% [markdown]
# #####               Searching and extracting from fruits

# %%
# Connceting the webdriver
driver = webdriver.Chrome()
time.sleep(2)

# Open url in chrome browser
driver.get('https://images.google.com/')

# %%
# searchbar
search = driver.find_element(By.XPATH,'//textarea[@jsname="yZiJbe"]')
search.clear()

# Search fruits
search.send_keys('Fruits')

# Click searchbutton
search_button = driver.find_element(By.CLASS_NAME,"zgAlFc")
search_button.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,700)")

images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)          
        
for i in range(len(img_urls)):
    if i > 10:
        break
    print("Downloading {0} of {1}images".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r'C:\Users\Sanjeet\Data Science\FlipRobo Inter\4_Handling Exceptoins\images\fruits\images'+str(i)+'.jpg','wb')
    file.write(response.content)
    
    driver.close()
# Out:
# Downloading 0 of 10images
# Downloading 1 of 10images
# Downloading 2 of 10images
# Downloading 3 of 10images
# Downloading 4 of 10images
# Downloading 5 of 10images
# Downloading 6 of 10images
# Downloading 7 of 10images
# Downloading 8 of 10images
# Downloading 9 of 10images
# Downloading 10 of 10images

# %% [markdown]
# ### Searching and extrating form cars

# %%
# Connceting the webdriver
driver = webdriver.Chrome()
time.sleep(2)

# Open url in chrome browser
driver.get('https://images.google.com/')

# %%
# Searching bar
search = driver.find_element(By.XPATH,'//textarea[@jsname="yZiJbe"]')
search.clear()
search.send_keys('cars')

# Click button
search_button = driver.find_element(By.XPATH,'//div[@class="zgAlFc"]')
search_button.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,700)")

images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')    
    
img_urls = []

for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i > 10:
        break
    print("Downloading {0} of {1}images".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r'C:\Users\Sanjeet\Data Science\FlipRobo Inter\4_Handling Exceptoins\images\cars\car'+str(i)+'.jpg','wb')
    file.write(response.content) 
    
    driver.close()
# Out:
# Downloading 0 of 10images
# Downloading 1 of 10images
# Downloading 2 of 10images
# Downloading 3 of 10images
# Downloading 4 of 10images
# Downloading 5 of 10images
# Downloading 6 of 10images
# Downloading 7 of 10images
# Downloading 8 of 10images
# Downloading 9 of 10images
# Downloading 10 of 10images

# %% [markdown]
# ### Searching and extrating from Maching Learning

# %%
# Connceting the webdriver
driver = webdriver.Chrome()
time.sleep(2)

# Open url in chrome browser
driver.get('https://images.google.com/')

# %%
# Search bar
search = driver.find_element(By.XPATH,'//textarea[@jsname="yZiJbe"]')
search.clear()
search.send_keys('Maching Learning')

# Search button
search_button = driver.find_element(By.XPATH,'//div[@class="zgAlFc"]')
search_button.click()

# %%
for _ in range(0,20):
    driver.execute_script("window.scrollBy(0,700)")
    
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls=[]

for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4]  == 'http'):
            img_urls.append(source)
        
for i in range(len(img_urls)):
    if i > 10:
        break
    print("Downloading {0} of {1}".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r'C:\Users\Sanjeet\Data Science\FlipRobo Inter\4_Handling Exceptoins\images\Maching Learning/ml_image'+str(i)+'.jpg','wb')
    file.write(response.content)
    
    driver.close()
# Out:
# Downloading 0 of 10
# Downloading 1 of 10
# Downloading 2 of 10
# Downloading 3 of 10
# Downloading 4 of 10
# Downloading 5 of 10
# Downloading 6 of 10
# Downloading 7 of 10
# Downloading 8 of 10
# Downloading 9 of 10
# Downloading 10 of 10

# %% [markdown]
# ### Searching and extracting from Guitar

# %%
# Connceting the webdriver
driver = webdriver.Chrome()
time.sleep(2)

# Open url in chrome browser
driver.get('https://images.google.com/')

# %%
# Search bar
search = driver.find_element(By.XPATH,'//textarea[@jsname="yZiJbe"]')
search.send_keys('Guitar')

# Search button
search_button = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search_button.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,700)")
    
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []

for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i > 10:
        break
    print("Downloading {0} of {1}".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\Sanjeet\Data Science\FlipRobo Inter\4_Handling Exceptoins\images\Guitar\image"+str(i)+".jpg",'wb')
    file.write(response.content)
    
    driver.close()
# Out:
# Downloading 0 of 10
# Downloading 1 of 10
# Downloading 2 of 10
# Downloading 3 of 10
# Downloading 4 of 10
# Downloading 5 of 10
# Downloading 6 of 10
# Downloading 7 of 10
# Downloading 8 of 10
# Downloading 9 of 10
# Downloading 10 of 10

# %% [markdown]
# ### Searching and extracting from cakes

# %%
# Connceting the webdriver
driver = webdriver.Chrome()
time.sleep(2)

# Open url in chrome browser
driver.get('https://images.google.com/')

# %%
# Searchbar 
search = driver.find_element(By.XPATH,'//textarea[@jsname="yZiJbe"]')
search.send_keys('Cakes')

# Search button
search_button = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search_button.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,700)")

images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []

for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i > 10:
        break
    print("Downloading {0} of {1}".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\Sanjeet\Data Science\FlipRobo Inter\4_Handling Exceptoins\images\Cakes\image"+str(i)+".jpg",'wb')
    file.write(response.content)
    
    driver.close()
# Out:
# Downloading 0 of 10
# Downloading 1 of 10
# Downloading 2 of 10
# Downloading 3 of 10
# Downloading 4 of 10
# Downloading 5 of 10
# Downloading 6 of 10
# Downloading 7 of 10
# Downloading 8 of 10
# Downloading 9 of 10
# Downloading 10 of 10

# %% [markdown]
# ***4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com
# and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand
# Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.***

# %%
# Connecting the webdriver
driver = webdriver.Chrome()

# Open the url in chrome browser
driver.get('https://www.flipkart.com/')

# %%
# Close Login details box
close_button = driver.find_element(By.XPATH,'//span[@role="button"]')
close_button.click()

# %%
# Searchbar
search = driver.find_element(By.XPATH,'//input[@class="Pke_EE"]')
search.clear()

# Search smartphone
search.send_keys('Oneplus Nord')

# search click button
search_button = driver.find_element(By.XPATH,'//button[@class="_2iLD__"]')
search_button.click()

# %%
# Create Empty list
Brand_name = []
Smartphone_name = []
Color = []
RAM = []
Storage = []
Primary_Camera =  []
Secondary_Camera = []
Display_Size = []
Battery_Capacity = []
Price = []

# %%
# Product_URL
Product_URL = []

url = driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in url:
    Product_URL.append(i.get_attribute('href'))

# %%
from tqdm import tqdm
for i in tqdm(Product_URL):
    driver.get(i)
    time.sleep(3)
    
     # Expanding specification table by clicking on read more button
    try:
        read_more = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        read_more.click()
    except NoSuchElementException:
        print('NoSuchElementException Occur')
        pass
    
    # Extracting brand name
    try:
        brand = driver.find_element(By.XPATH,'//h1[@class="yhB1nd"]')
        Brand_name.append(brand.text.split()[0])
    except NoSuchElementException:
        Brand_name.append('-')
        
    # Extracting Smartphone_name
    try:
        smartphone = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')
        Smartphone_name.append(smartphone.text)
    except NoSuchElementException:
        Smartphone_name.append('-')
        
    # Extracting Color
    try:
        color = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        Color.append(color.text)
    except NoSuchElementException:
        Color.append('-')
        
    # Extracting RAM
    try:
        ram = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[2]/td[2]/ul/li')
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-')
    
    # Extracting Storage
    try:
        storage = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]/ul/li')
        Storage.append(storage.text)
    except NoSuchElementException:
        Storage.append('-')
    
    # Extracting Primary_Camera
    try:
        p_camera = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[1]/td[2]/ul/li')
        Primary_Camera.append(p_camera.text)
    except NoSuchElementException:
        Primary_Camera.append('-')
        
    # Extracting Secondary_Camera
    try:
        s_camera = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[2]/td[2]/ul/li')
        Secondary_Camera.append(s_camera.text)
    except NoSuchElementException:
        Secondary_Camera.append('-')
    
    # Extracting Display_Size
    try:
        display = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table/tbody/tr[1]/td[2]/ul/li')
        Display_Size.append(display.text)
    except NoSuchElementException:
        Display_Size.append('-')
        
    # Extracting Battery_Capacity
    try:
        battery = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][7]/table/tbody/tr[1]/td[2]/ul/li')
        Battery_Capacity.append(battery.text)
    except NoSuchElementException:
        Battery_Capacity.append('-')
        
    # Extracting Price
    try:
        price = driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        Price.append(price.text.replace('₹',''))
    except NoSuchElementException:
        Price.append('-')
        
    driver.close()
# Out:
# 100%|██████████| 24/24 [02:23<00:00,  5.99s/it]

# %%
print(len(Brand_name),len(Smartphone_name),len(Color),len(RAM),len(Storage),len(Primary_Camera),len(Secondary_Camera),len(Display_Size),len(Battery_Capacity),len(Price))
# Out:
# 24 24 24 24 24 24 24 24 24 24

# %%
# Creating dataframe
OnePlus = pd.DataFrame({'Brand name':Brand_name,'Smartphone name':Smartphone_name,'Color':Color,'RAM':RAM,'Storage(ROM)':Storage,'Primary Camera':Primary_Camera,'Secondary Camera':Secondary_Camera,'Display Size':Display_Size,'Battery Capacity':Battery_Capacity,'Price':Price})

OnePlus
# Out:
#    Brand name    Smartphone name           Color    RAM Storage(ROM)  \
# 0     OnePlus  Nord CE 2 Lite 5G       Blue Tide   6 GB       128 GB
# 1     OnePlus  Nord CE 2 Lite 5G      Black Dusk   6 GB       128 GB
# 2     OnePlus  Nord CE 3 Lite 5G     Pastel Lime   8 GB       256 GB
# 3     OnePlus  Nord CE 3 Lite 5G  Chromatic Gray   8 GB       256 GB
# 4     OnePlus  Nord CE 3 Lite 5G     Pastel Lime   8 GB       128 GB
# 5     OnePlus  Nord CE 3 Lite 5G  Chromatic Gray   8 GB       128 GB
# 6     OnePlus        Nord CE3 5G      Aqua Surge   8 GB       128 GB
# 7     OnePlus        Nord CE3 5G      Aqua Surge  12 GB       256 GB
# 8     OnePlus        Nord CE3 5G    Grey Shimmer  12 GB       256 GB
# 9     OnePlus          Nord 3 5G     Misty Green   8 GB       128 GB
# 10    OnePlus          Nord 3 5G     Misty Green  16 GB       256 GB
# 11    OnePlus          Nord 3 5G    Tempest Gray  16 GB       256 GB
# 12    OnePlus         Nord 2T 5G     Gray Shadow   8 GB       128 GB
# 13    OnePlus        Nord CE3 5G    Grey Shimmer   8 GB       128 GB
# 14    OnePlus          Nord 3 5G    Tempest Gray   8 GB       128 GB
# 15    OnePlus         Nord 2T 5G     Gray Shadow  12 GB       256 GB
# 16    OnePlus       Nord CE 2 5G     Bahama Blue   8 GB       128 GB
# 17    OnePlus         Nord 2T 5G        Jade Fog  12 GB       256 GB
# 18    OnePlus          Nord 2 5G       Blue Haze   8 GB       128 GB
# 19    OnePlus          Nord 2 5G       Blue Haze  12 GB       256 GB
# 20    OnePlus          Nord 2 5G         PAC-MAN  12 GB       256 GB
# 21    OnePlus          Nord 2 5G     Gray Sierra  12 GB       256 GB
# 22    OnePlus               Nord        Gray Ash  12 GB       256 GB
# 23    OnePlus         Nord 2T 5G        Jade Fog   8 GB       128 GB
#
#        Primary Camera   Secondary Camera          Display Size  \
# 0    64MP Rear Camera  16MP Front Camera  16.74 cm (6.59 inch)
# 1    64MP Rear Camera  16MP Front Camera  16.74 cm (6.59 inch)
# 2   108MP Rear Camera     Primary Camera  17.07 cm (6.72 inch)
# 3   108MP Rear Camera     Primary Camera  17.07 cm (6.72 inch)
# 4   108MP Rear Camera     Primary Camera  17.07 cm (6.72 inch)
# 5   108MP Rear Camera     Primary Camera  17.07 cm (6.72 inch)
# 6    50MP Rear Camera     Primary Camera   17.02 cm (6.7 inch)
# 7    50MP Rear Camera     Primary Camera   17.02 cm (6.7 inch)
# 8    50MP Rear Camera     Primary Camera   17.02 cm (6.7 inch)
# 9    50MP Rear Camera     Primary Camera  17.12 cm (6.74 inch)
# 10   50MP Rear Camera     Primary Camera  17.12 cm (6.74 inch)
# 11   50MP Rear Camera     Primary Camera  17.12 cm (6.74 inch)
# 12   50MP Rear Camera  32MP Front Camera   17.02 cm (6.7 inch)
# 13   50MP Rear Camera     Primary Camera   17.02 cm (6.7 inch)
# 14   50MP Rear Camera     Primary Camera  17.12 cm (6.74 inch)
# 15   50MP Rear Camera                  -   17.02 cm (6.7 inch)
# 16   64MP Rear Camera     Primary Camera  16.33 cm (6.43 inch)
# 17   50MP Rear Camera                  -   17.02 cm (6.7 inch)
# 18   50MP Rear Camera     Primary Camera  16.33 cm (6.43 inch)
# 19   50MP Rear Camera     Primary Camera  16.33 cm (6.43 inch)
# 20   50MP Rear Camera     Primary Camera  16.33 cm (6.43 inch)
# 21   50MP Rear Camera                  -  16.33 cm (6.43 inch)
# 22                Yes  48MP + 48MP + 8MP  16.36 cm (6.44 inch)
# 23   50MP Rear Camera  32MP Front Camera   17.02 cm (6.7 inch)
#
#    Battery Capacity   Price
# 0          5000 mAh  17,079
# 1          5000 mAh  16,976
# 2          5000 mAh  21,992
# 3          5000 mAh  21,993
# 4          5000 mAh  19,999
# 5          5000 mAh  19,999
# 6          5000 mAh  25,709
# 7          5000 mAh  28,969
# 8          5000 mAh  28,699
# 9          5000 mAh  32,850
# 10         5000 mAh  37,845
# 11         5000 mAh  37,280
# 12         4500 mAh  26,984
# 13         5000 mAh  25,970
# 14         5000 mAh  31,735
# 15         4500 mAh  33,188
# 16         4500 mAh  24,990
# 17         4500 mAh  33,999
# 18         4500 mAh  30,599
# 19         4500 mAh  34,999
# 20         4500 mAh  34,990
# 21         4500 mAh  33,990
# 22               5G  28,990
# 23         4500 mAh  26,578

# %% [markdown]
# ### 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
# Connecting the webdriver
driver = webdriver.Chrome()

# Open the url in google chrome
driver.get('https://www.google.co.in/maps')
user_input=input("Enter city name for which coordinates is required : ")
time.sleep(5)

# Search bar
search = driver.find_element(By.XPATH,'//input[@jslog="11886"]')
search.send_keys(user_input)

# Search Button
search_button = driver.find_element(By.XPATH,'//button[@jslog="11887"]')
search_button.click()
time.sleep(5)

lat = []
long = []

try: 
    url_string = driver.current_url
    print("URL Extracted",url_string)
    lat_long = re.findall(r'@(.*)data',url_string)   
    if len(lat_long):
        lat_long_list = lat_long[0].split(",")
        if len(lat_long_list)>=2:
            lat.append(lat_long_list[0])
            long.append(lat_long_list[1])
except Exception as e:
    print("error:",str(e))

time.sleep(2)
driver.close()

location_data=pd.DataFrame({'Enter Location':user_input,'latitude':lat,'longitude':long})
location_data
# Out:
# Enter city name for which coordinates is required : Rewari
# URL Extracted https://www.google.co.in/maps/place/Rewari,+Haryana+123401/@28.1990283,76.5787746,13z/data=!3m1!4b1!4m6!3m5!1s0x390d50719ae37551:0xe4c45afc4faedcee!8m2!3d28.1919738!4d76.6190774!16zL20vMDk4MHNj?entry=ttu
#   Enter Location    latitude   longitude
# 0         Rewari  28.1990283  76.5787746

# %% [markdown]
# ###  7. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped:“Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
# Connecting the webdriver
driver = webdriver.Chrome()

# Open the url in chrome browser
driver.get('https://www.forbes.com/')
time.sleep(1)

# %%
# Clicking on explore button to expand menu
driver.find_element(By.XPATH,'//div[@role="button"]').click()

# Clicking on Billionaire category
driver.find_element(By.XPATH,'//ul[@class="E-S7Afho"]/li[2]/div[1]').click()

# Clicking on world billionaire tab
driver.find_element(By.XPATH,'//ul[@class="E-S7Afho"]/li[2]/div[2]/div[3]/ul[1]/li[1]/a').click()

# %%
# Empty list to scrap data
Rank =[]
Name=[]
Net_worth=[]
Age=[]
Citizenship=[]
Source=[]
Industry=[]

# %%
# Extracting Rank No
rank=driver.find_elements(By.XPATH,'//div[@class="Table_rank___YBhk Table_dataCell__2QCve"]')
for i in rank:
    Rank.append(i.text)
    
# Extacting name
name=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][2]')
for i in name:
    Name.append(i.text)
    
#Extracting Net worth
net=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][3]')
for i in net:
    Net_worth.append(i.text)
    
# Extracting Age
age=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][4]')
for i in age:
    Age.append(i.text)
    
 # Extracting Citizenship
citizen=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][5]')
for i in citizen:
    Citizenship.append(i.text)
    
# Extracting Source
source=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][6]')
for i in source:
    Source.append(i.text)

# Extracting Industry
industry=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][7]')
for i in industry:
    Industry.append(i.text)
    
driver.close()

# %%
print(len(Rank),len(Name),len(Net_worth),len(Age),len(Citizenship),len(Source),len(Industry))
# Out:
# 200 200 200 200 200 200 200

# %%
#creating dataframe
Forbes_list=pd.DataFrame({'Rank':Rank,'Name':Name,'Net Worth':Net_worth,'Age':Age,'Citizenship':Citizenship,'Source':Source,'Industry':Industry})
print('\033[1m'+' Forbes World Billionaires List Oct 2021 :'+'\033[0m')
Forbes_list
# Out:
#  Forbes World Billionaires List Oct 2021 :
#     Rank                      Name Net Worth Age    Citizenship  \
# 0      1  Bernard Arnault & family    $211 B  74         France
# 1      2                 Elon Musk    $180 B  51  United States
# 2      3                Jeff Bezos    $114 B  59  United States
# 3      4             Larry Ellison    $107 B  78  United States
# 4      5            Warren Buffett    $106 B  92  United States
# ..   ...                       ...       ...  ..            ...
# 195  195               Jin Baofang    $9.6 B  70          China
# 196  195        Luo Liguo & family    $9.6 B  67          China
# 197  195              Marijke Mars    $9.6 B  58  United States
# 198  195               Pamela Mars    $9.6 B  62  United States
# 199  195              Valerie Mars    $9.6 B  64  United States
#
#                  Source Industry
# 0                  LVMH
# 1         Tesla, SpaceX
# 2                Amazon
# 3                Oracle
# 4    Berkshire Hathaway
# ..                  ...      ...
# 195        Solar panels
# 196           Chemicals
# 197     Candy, pet food
# 198     Candy, pet food
# 199     Candy, pet food
#
# [200 rows x 7 columns]

# %% [markdown]
# ### 8. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
# Connecting to webdriver
driver=webdriver.Chrome()
time.sleep(1)

# Opening url in chrome browser
driver.get('https://www.youtube.com/')
time.sleep(3)

# %%
# Finding search menu
Search=driver.find_element(By.XPATH,'//input[@id="search"]') 
Search.send_keys('GAME (Full Video) Shooter Kahlon')

# Clicking search button
Search_button=driver.find_element(By.XPATH,'//button[@id="search-icon-legacy"]')  
Search_button.click()
time.sleep(2)

# %%
# Clicking on video
link = driver.find_element(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-video-renderer"]')
link.click()
time.sleep(3)

# %%
# Empty lists to scrap data
Comments = []
Comment_posted_ago = []
Timeline = []
Likes = []
No_of_Likes = []

# %%
# Scrolling window using ScrollBy method from 0 pixel to 15000 pixel
for _ in range(10000):
    driver.execute_script("window.scrollBy(0,70000)")


#extracting comment on video
comment = driver.find_elements(By.ID,"content-text")
time.sleep(5)

for i in comment:
    if i.text is None:
        Comments.append("--")
    else:
        Comments.append(i.text)
time.sleep(5)

# Extracting time of commenting
timeline = driver.find_elements(By.XPATH,"//a[contains(text(),'ago')]")
time.sleep(3)

for i in timeline:
    if i.text is None:
        Timeline.append("-")
    else:
        Timeline.append(i.text)
for i in range(0,len(Timeline),2):
    Comment_posted_ago.append(Timeline[i])

# %%
len(Comments),len(Comment_posted_ago)
# Out:
# (560, 1180)

# %%
YT=pd.DataFrame({})
YT['Comments']=Comments[:500]
YT['Comment Posted Ago']=Comment_posted_ago[:500]
YT
# Out:
#                                               Comments    Comment Posted Ago
# 0    Talent has no boundaries I'm from Pakistan but...            1 year ago
# 1                                     Legend never die           3 weeks ago
# 2    It's gonna be approx. 3 years but this song st...            8 days ago
# 3    Shooter Kahlon lyrics also gives a lot of moti...          2 months ago
# 4             This song give us highly motivated vibes             1 day ago
# ..                                                 ...                   ...
# 495                                 Legend never die ️           1 month ago
# 496                                   LEGEND NEVER DIE  2 weeks ago (edited)
# 497                                   Legend never Die          5 months ago
# 498  When the sidhu's lines start my heart beating ...          2 months ago
# 499  This song give me extra motivation ️️ miss you...           3 years ago
#
# [500 rows x 2 columns]

# %% [markdown]
# ### 9. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# Connecting to webdriver
driver = webdriver.Chrome()

try:
    # Opening url in chrome browser
    driver.get("https://www.hostelworld.com/")

    loc = driver.find_element(
        By.XPATH,
        "/html/body/div[3]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/div/input",
    )

    loc.send_keys("london")
    search_btn = driver.find_element(
        By.XPATH,
        "/html/body/div[3]/div/div/div[2]/div[1]/div/div/div[4]/div/div[2]/div/div[5]/button",
    )
    search_btn.click()

except Exception as e:

    driver.get(
        "https://www.hostelworld.com/s?q=London, England&country=England&city=London&type=city&id=3&from=2022-07-28&to=2022-07-31&guests=2&HostelNumber"
    )

time.sleep(3)

# %%
hostel_name = []
location = []
ratings = []
total_reviews = []
overall_reviews = []
private_price = []
dorm_price = []

# %%
URL = []
start = 0
end = 1
for page in range(start,end):
    url = driver.find_elements(By.XPATH,'//a[@rel="noreferrer noopener"]')
    for i in url:
        URL.append(i.get_attribute('href'))
    time.sleep(2)
    next_button = driver.find_elements(By.XPATH,'//button[@class="pill-content page-nav nav-right icon-only"]')

# %%
# iterating each and every url to fectch
from tqdm import tqdm
for i in tqdm(URL):
    driver.get(i)
    time.sleep(3)
    
    # Extracting Hotel_name
    name_tag = driver.find_elements()
